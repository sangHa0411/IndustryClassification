# %%
import matplotlib.pyplot as plt
from datasets import load_dataset

# %%
dset = load_dataset('sh110495/IndustryClassification')
# Out:
# Reusing dataset nli (/Users/sanghapark/.cache/huggingface/datasets/sh110495___nli/IndustryClassification 1.0/1.0.0/20974de9b4515b11e4e9f85eb63d6ff0a1cbc99011469786ccc4a4595822afc8)
# 100%|██████████| 2/2 [00:00<00:00, 11.20it/s]

# %%
type(dset['train']
# Out:
# Dataset({
#     features: ['AI_id', 'digit_1', 'digit_2', 'digit_3', 'text_obj', 'text_mthd', 'text_deal'],
#     num_rows: 1000000
# })

# %%
dset['train'][29]['text_deal'] == 'nan'
# Out:
# True
